# %% [markdown]
# # WMIR practice lesson on Spacy
#
# ### Objective
# Use the Spacy framework to extract relevant information from sentences for enriching the representations.
# Train several models and compare them with and without the enriched representations.
#
# #### Author
# Claudiu Daniel Hromei, April 2023.
# hromei@ing.uniroma2.it

# %% [markdown]
# # Introduction
#
# [SpaCy](spacy.io) is a free, open-source library for Natural Language Processing (NLP) in Python. It can be used to build information extraction or natural language understanding systems, or to pre-process text for deep learning.
# Some Features:
# - **Tokenization**: Segmenting text into words, punctuations marks etc.
# - **Part-of-speech (POS) Tagging**: Assigning word types to tokens, like verb or noun.
# - **Dependency Parsing**: Assigning syntactic dependency labels, describing the relations between individual tokens, like subject or object.
# - **Lemmatization**: Assigning the base forms of words. For example, the lemma of “was” is “be”, and the lemma of “rats” is “rat”.
# - **Sentence Boundary Detection (SBD)**: Finding and segmenting individual sentences.
# - **Named Entity Recognition (NER)**: Labelling named “real-world” objects, like persons, companies or locations.
# - **Entity Linking (EL)**: Disambiguating textual entities to unique identifiers in a knowledge base.
# - **Similarity**: Comparing words, text spans and documents and how similar they are to each other.
# - **Text Classification**: Assigning categories or labels to a whole document, or parts of a document.
# - **Rule-based Matching**: Finding sequences of tokens based on their texts and linguistic annotations, similar to regular expressions.
# - **Training**: Updating and improving a statistical model’s predictions.
# - **Serialization**: Saving objects to files or byte strings.

# %% [markdown]
# # Required Libraries

# %%
import pandas as pd

from IPython.display import display, HTML

# %%
# option to print all the value of cells in DataFrames
pd.set_option("max_colwidth", None)

# %% [markdown]
# ### Install spacy and download the english pipeline

# %%
# install the spacy module
# !pip install spacy

# download the english pipeline here
# 'it_core_news_sm' for italian texts
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\simon\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (1.10.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (1.21.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (1.1.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (0.7.0)
# Requirement already satisfied: setuptools in c:\users\simon\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: jinja2 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (8.1.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\simon\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\simon\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\simon\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\simon\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\simon\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: colorama in c:\users\simon\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\simon\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\simon\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      --------------------------------------- 12.8/12.8 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\simon\anaconda3\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.2)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.28.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (5.2.1)
# Requirement already satisfied: jinja2 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.11.3)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.21.5)
# Requirement already satisfied: setuptools in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (63.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (21.3)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\simon\anaconda3\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\simon\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\simon\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\simon\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\simon\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\simon\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\simon\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\simon\anaconda3\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\simon\anaconda3\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
from spacy import displacy
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Annotation example

# %%
input_string = "In 1982, Mark drove his car from Los Angeles to Las Vegas until 5 of july"
nlp = spacy.load('en_core_web_sm')

# %%
def print_annotation(input_string):
    doc = nlp(input_string)
    
    df = pd.DataFrame({
        "id": [],
        "token": [],
        "lemma": [],
        "tag": [],
        "entity": [],
        "dependency": [],
        "head id": []
    })

    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {"id": str(i+1), "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": str(head_idx)}
            df = df.append(word_obj, ignore_index=True)
    display(df)

# %%
print_annotation(input_string) #Entity: O-->Not an entity Head id: how many dependency there are in the graph containing that word (how amny arrows to reach the root)
# Out:
#     id    token    lemma   tag  entity dependency head id
# 0    1       In       in    IN       O       prep       5
# 1    2     1982     1982    CD    DATE       pobj       1
# 2    3        ,        ,     ,       O      punct       5
# 3    4     Mark     Mark   NNP  PERSON      nsubj       5
# 4    5    drove    drive   VBD       O       ROOT       0
# 5    6      his      his  PRP$       O       poss       7
# 6    7      car      car    NN       O       dobj       5
# 7    8     from     from    IN       O       prep       5
# 8    9      Los      Los   NNP     GPE   compound      10
# 9   10  Angeles  Angeles   NNP     GPE       pobj       8
# 10  11       to       to    IN       O       prep       5
# 11  12      Las      Las   NNP     GPE   compound      13
# 12  13    Vegas    Vegas   NNP     GPE       pobj      11
# 13  14    until    until    IN       O       prep       5
# 14  15        5        5    CD    DATE       pobj      14
# 15  16       of       of    IN    DATE       prep      15
# 16  17     july     july   NNP    DATE       pobj      16

# %%
def visualize_annotation(input_string, style="dep"):
    doc = nlp(input_string)
    # style can be either "dep" or "ent"
    displacy.render(doc, style=style, jupyter=True, options={"distance": 100}) #distance default 140, visualization metric
    #Jupyter=true --> use no server

# %%
visualize_annotation(input_string, style="dep")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a402fb897a0e4bfcb7c7b4ade36b0029-0" class="displacy" width="1650" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">1982,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">Mark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">drove</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">his</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Los</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Angeles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">Las</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">Vegas</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">until</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">july</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-0" stroke-width="2px" d="M70,252.0 C70,152.0 335.0,152.0 335.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,254.0 L62,242.0 78,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-1" stroke-width="2px" d="M70,252.0 C70,202.0 130.0,202.0 130.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M130.0,254.0 L138.0,242.0 122.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-2" stroke-width="2px" d="M270,252.0 C270,202.0 330.0,202.0 330.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,254.0 L262,242.0 278,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-3" stroke-width="2px" d="M470,252.0 C470,202.0 530.0,202.0 530.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,254.0 L462,242.0 478,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-4" stroke-width="2px" d="M370,252.0 C370,152.0 535.0,152.0 535.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,254.0 L543.0,242.0 527.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-5" stroke-width="2px" d="M370,252.0 C370,102.0 640.0,102.0 640.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M640.0,254.0 L648.0,242.0 632.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a402fb897a0e4bfcb7c7b4ade36b0029-0-6" stroke-width="2px" d="M770,252.0 C770,202.0 830.0,202.0 830.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style=

# %%
visualize_annotation(input_string, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1982
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drove his car from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  until
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 of july
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
visualize_annotation(input_string, style="span")
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">In 1982 , Mark drove his car from Los Angeles to Las Vegas until 5 of july </div></span>

# %% [markdown]
# # Information extraction
#
# Get information about a particular word in a given string.

# %%
def get_word_annotation(input_string, word_string):
    doc = nlp(input_string)
    
    words = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {"id": i+1, "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": head_idx}
            words.append(word_obj)
    
    for word in words:
        if word["token"] == word_string:
            return word
    
    return None

# %%
print(get_word_annotation(input_string, "Mark"))
print(get_word_annotation(input_string, "1982"))
# Out:
# {'id': 4, 'token': 'Mark', 'lemma': 'Mark', 'tag': 'NNP', 'entity': 'PERSON', 'dependency': 'nsubj', 'head id': 5}
# {'id': 2, 'token': '1982', 'lemma': '1982', 'tag': 'CD', 'entity': 'DATE', 'dependency': 'pobj', 'head id': 1}

# %% [markdown]
# ### Exercise 1: Search for relations
#
# Define a method that takes in input a sentence (`input_string`) and the name of a relation (`relation_string`), parses with spacy the input and returns the words (the `objects`! not the strings) involved in the relation. If the relation is not present, return an empty array.
#
# ```
# def search_relation(input_string, relation_string):
#     return word_obj_list
# ```

# %%
def get_word_relation(input_string, relation_String):
    doc = nlp(input_string)
    
    words = []
    ret = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {"id": i+1, "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": head_idx}
            words.append(word_obj)
    
    for word in words:
        if word["dependency"] == relation_String:
            ret.append(word)
    if(ret == []):
        ret = None
    return ret

# %%
get_word_relation(input_string,"prep")
# Out:
# [{'id': 1,
#   'token': 'In',
#   'lemma': 'in',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 5},
#  {'id': 8,
#   'token': 'from',
#   'lemma': 'from',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 5},
#  {'id': 11,
#   'token': 'to',
#   'lemma': 'to',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 5},
#  {'id': 14,
#   'token': 'until',
#   'lemma': 'until',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 5},
#  {'id': 16,
#   'token': 'of',
#   'lemma': 'of',
#   'tag': 'IN',
#   'entity': 'DATE',
#   'dependency': 'prep',
#   'head id': 15}]

# %%
def get_word_relation_2(input_string, relation_String):
    doc = nlp(input_string)
    
    words = []
    ret = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {"id": i+1, "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": head_idx}
            words.append(word_obj)
    
    for word in words:
        if word["dependency"] == relation_String:
            l = []
            for w in words:
                if(word["head id"] == w["id"]):
                    l.append(w["lemma"])
                    break
            l.append(word["lemma"])
            l.append(word["dependency"])
            ret.append(l)
            
    if(not ret):
        ret = None
    return ret

# %%
get_word_relation_2(input_string,"compound")
# Out:
# [['Angeles', 'Los', 'compound'], ['Vegas', 'Las', 'compound']]

# %%
print_annotation(input_string)
# Out:
#     id    token    lemma   tag  entity dependency head id
# 0    1       In       in    IN       O       prep       5
# 1    2     1982     1982    CD    DATE       pobj       1
# 2    3        ,        ,     ,       O      punct       5
# 3    4     Mark     Mark   NNP  PERSON      nsubj       5
# 4    5    drove    drive   VBD       O       ROOT       0
# 5    6      his      his  PRP$       O       poss       7
# 6    7      car      car    NN       O       dobj       5
# 7    8     from     from    IN       O       prep       5
# 8    9      Los      Los   NNP     GPE   compound      10
# 9   10  Angeles  Angeles   NNP     GPE       pobj       8
# 10  11       to       to    IN       O       prep       5
# 11  12      Las      Las   NNP     GPE   compound      13
# 12  13    Vegas    Vegas   NNP     GPE       pobj      11
# 13  14    until    until    IN       O       prep       5
# 14  15        5        5    CD    DATE       pobj      14
# 15  16       of       of    IN    DATE       prep      15
# 16  17     july     july   NNP    DATE       pobj      16

# %% [markdown]
# ### Exercise 2: Search for entities
#
# Define a method that takes in input a sentence (`input_string`) and the name of an entity type (`entity_type_string`), parses with spacy the input and returns the words (the `objects`! not the strings) described by that entity. If the entity type is not present, return an empty array.
#
# ```
# def search_entity(input_string, entity_type_string):
#     return word_obj_list
# ```

# %%
def search_entity(input_string, entity_type_string):
    doc = nlp(input_string)
    
    words = []
    ret = []
    for sent in doc.sents:
        for i, word in enumerate(sent):
            if word.head is word:
                head_idx = 0
            else:
                head_idx = doc[i].head.i+1
            if head_idx == i + 1:
                head_idx = 0

            entity_tag = word.ent_type_
            if len(entity_tag) == 0:
                entity_tag = "O"
            
            word_obj = {"id": i+1, "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": head_idx}
            words.append(word_obj)
    
    i=0
    while(i<len(words)):
        res = []
        while(i<len(words) and words[i]["entity"] == entity_type_string):
            res.append(words[i]["lemma"])
            i=i+1
        if(res):
            ret.append(" ".join(res))
        i=i+1
            
    if(not ret):
        ret = None
                          
    return ret

# %%
search_entity(input_string,"GPE")
# Out:
# ['Los Angeles', 'Las Vegas']

# %%
visualize_annotation(input_string, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1982
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drove his car from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Los Angeles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  until
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 of july
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </div></span>

# %%
search_entity(input_string,"DATE")
# Out:
# ['1982', '5 of july']

# %% [markdown]
# ### Exercise 3: Enriching the sentences
#
# For every sentence in the QuestionClassification dataset, extract the `subject-verb` relation and the `verb-object` relation. Add these couples to the original input, divided by the `#`:
#
# - Sentence: '*What is the full form of .com?*'
# - `subject-verb`: *What is*
# - `verb-object`: *is the full form*
# - Enriched sentence: '*What is the full form of .com? # What is # is the full form*'
#
# Store the enriched sentences in a new dataframe and train a classifier (SVM, NB, Rocchio..) and evaluate it.

# %%
from sklearn.datasets import fetch_20newsgroups
# Load the Reuters dataset
newsgroups_train = fetch_20newsgroups(subset='train', shuffle=True, random_state=42, remove=('headers', 'footers', 'quotes'))
newsgroups_test = fetch_20newsgroups(subset='test', shuffle=True, random_state=42, remove=('headers', 'footers', 'quotes'))

# %%
print_annotation(newsgroups_train.data[0])
# Out:
#      id      token   lemma  tag entity dependency head id
# 0     1          I       I  PRP      O      nsubj       3
# 1     2        was      be  VBD      O        aux       3
# 2     3  wondering  wonder  VBG      O       ROOT       0
# 3     4         if      if   IN      O       mark       9
# 4     5     anyone  anyone   NN      O      nsubj       9
# ..   ..        ...     ...  ...    ...        ...     ...
# 111  37     please  please   UH      O       intj      36
# 112  38          e       e   NN      O       dobj      39
# 113  39          -       -   NN      O       dobj      33
# 114  40       mail    mail   NN      O       dobj      22
# 115  41          .       .    .      O      punct      43
#
# [116 rows x 7 columns]

# %%
nlps = []
for i in newsgroups_train.data:
    nlps.append(nlp(i))

# %%
target = nlps[0]
print_annotation(target)
# Out:
#      id      token   lemma  tag entity dependency head id
# 0     1          I       I  PRP      O      nsubj       3
# 1     2        was      be  VBD      O        aux       3
# 2     3  wondering  wonder  VBG      O       ROOT       0
# 3     4         if      if   IN      O       mark       9
# 4     5     anyone  anyone   NN      O      nsubj       9
# ..   ..        ...     ...  ...    ...        ...     ...
# 111  37     please  please   UH      O       intj      36
# 112  38          e       e   NN      O       dobj      39
# 113  39          -       -   NN      O       dobj      33
# 114  40       mail    mail   NN      O       dobj      22
# 115  41          .       .    .      O      punct      43
#
# [116 rows x 7 columns]

# %%
words = []

for sent in target.sents:
    for i, word in enumerate(sent):
        if word.head is word:
            head_idx = 0
        else:
            head_idx = target[i].head.i+1
        if head_idx == i + 1:
            head_idx = 0

        entity_tag = word.ent_type_
        if len(entity_tag) == 0:
            entity_tag = "O"
            
        word_obj = {"id": i+1, "token": str(word), "lemma": word.lemma_, "tag": word.tag_, "entity": entity_tag,
                                    "dependency": word.dep_, "head id": head_idx}
        words.append(word_obj)

# %%
words
# Out:
# [{'id': 1,
#   'token': 'I',
#   'lemma': 'I',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 3},
#  {'id': 2,
#   'token': 'was',
#   'lemma': 'be',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'aux',
#   'head id': 3},
#  {'id': 3,
#   'token': 'wondering',
#   'lemma': 'wonder',
#   'tag': 'VBG',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 0},
#  {'id': 4,
#   'token': 'if',
#   'lemma': 'if',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'mark',
#   'head id': 9},
#  {'id': 5,
#   'token': 'anyone',
#   'lemma': 'anyone',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 9},
#  {'id': 6,
#   'token': 'out',
#   'lemma': 'out',
#   'tag': 'RB',
#   'entity': 'O',
#   'dependency': 'advmod',
#   'head id': 7},
#  {'id': 7,
#   'token': 'there',
#   'lemma': 'there',
#   'tag': 'RB',
#   'entity': 'O',
#   'dependency': 'advmod',
#   'head id': 5},
#  {'id': 8,
#   'token': 'could',
#   'lemma': 'could',
#   'tag': 'MD',
#   'entity': 'O',
#   'dependency': 'aux',
#   'head id': 9},
#  {'id': 9,
#   'token': 'enlighten',
#   'lemma': 'enlighten',
#   'tag': 'VB',
#   'entity': 'O',
#   'dependency': 'advcl',
#   'head id': 15},
#  {'id': 10,
#   'token': 'me',
#   'lemma': 'I',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 9},
#  {'id': 11,
#   'token': 'on',
#   'lemma': 'on',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 9},
#  {'id': 12,
#   'token': 'this',
#   'lemma': 'this',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 13},
#  {'id': 13,
#   'token': 'car',
#   'lemma': 'car',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 11},
#  {'id': 14,
#   'token': 'I',
#   'lemma': 'I',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 15},
#  {'id': 15,
#   'token': 'saw',
#   'lemma': 'see',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'ccomp',
#   'head id': 3},
#  {'id': 16,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'O',
#   'dependency': 'dep',
#   'head id': 15},
#  {'id': 17,
#   'token': 'the',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'DATE',
#   'dependency': 'det',
#   'head id': 19},
#  {'id': 18,
#   'token': 'other',
#   'lemma': 'other',
#   'tag': 'JJ',
#   'entity': 'DATE',
#   'dependency': 'amod',
#   'head id': 19},
#  {'id': 19,
#   'token': 'day',
#   'lemma': 'day',
#   'tag': 'NN',
#   'entity': 'DATE',
#   'dependency': 'dobj',
#   'head id': 15},
#  {'id': 20,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 3},
#  {'id': 1,
#   'token': 'It',
#   'lemma': 'it',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 3},
#  {'id': 2,
#   'token': 'was',
#   'lemma': 'be',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 3},
#  {'id': 3,
#   'token': 'a',
#   'lemma': 'a',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 0},
#  {'id': 4,
#   'token': '2',
#   'lemma': '2',
#   'tag': 'CD',
#   'entity': 'CARDINAL',
#   'dependency': 'nummod',
#   'head id': 9},
#  {'id': 5,
#   'token': '-',
#   'lemma': '-',
#   'tag': 'HYPH',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 9},
#  {'id': 6,
#   'token': 'door',
#   'lemma': 'door',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'compound',
#   'head id': 7},
#  {'id': 7,
#   'token': 'sports',
#   'lemma': 'sport',
#   'tag': 'NNS',
#   'entity': 'O',
#   'dependency': 'compound',
#   'head id': 5},
#  {'id': 8,
#   'token': 'car',
#   'lemma': 'car',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'attr',
#   'head id': 9},
#  {'id': 9,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 15},
#  {'id': 10,
#   'token': 'looked',
#   'lemma': 'look',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'conj',
#   'head id': 9},
#  {'id': 11,
#   'token': 'to',
#   'lemma': 'to',
#   'tag': 'TO',
#   'entity': 'O',
#   'dependency': 'aux',
#   'head id': 9},
#  {'id': 12,
#   'token': 'be',
#   'lemma': 'be',
#   'tag': 'VB',
#   'entity': 'O',
#   'dependency': 'xcomp',
#   'head id': 13},
#  {'id': 13,
#   'token': 'from',
#   'lemma': 'from',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 11},
#  {'id': 14,
#   'token': 'the',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'DATE',
#   'dependency': 'det',
#   'head id': 15},
#  {'id': 15,
#   'token': 'late',
#   'lemma': 'late',
#   'tag': 'JJ',
#   'entity': 'DATE',
#   'dependency': 'amod',
#   'head id': 3},
#  {'id': 16,
#   'token': '60s/',
#   'lemma': '60s/',
#   'tag': 'CD',
#   'entity': 'DATE',
#   'dependency': 'pobj',
#   'head id': 15},
#  {'id': 17,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'DATE',
#   'dependency': 'dep',
#   'head id': 19},
#  {'id': 18,
#   'token': 'early',
#   'lemma': 'early',
#   'tag': 'JJ',
#   'entity': 'DATE',
#   'dependency': 'amod',
#   'head id': 19},
#  {'id': 19,
#   'token': '70s',
#   'lemma': '70',
#   'tag': 'NNS',
#   'entity': 'DATE',
#   'dependency': 'pobj',
#   'head id': 15},
#  {'id': 20,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 3},
#  {'id': 1,
#   'token': 'It',
#   'lemma': 'it',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubjpass',
#   'head id': 3},
#  {'id': 2,
#   'token': 'was',
#   'lemma': 'be',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'auxpass',
#   'head id': 3},
#  {'id': 3,
#   'token': 'called',
#   'lemma': 'call',
#   'tag': 'VBN',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 0},
#  {'id': 4,
#   'token': 'a',
#   'lemma': 'a',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 9},
#  {'id': 5,
#   'token': 'Bricklin',
#   'lemma': 'Bricklin',
#   'tag': 'NNP',
#   'entity': 'GPE',
#   'dependency': 'oprd',
#   'head id': 9},
#  {'id': 6,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 7},
#  {'id': 1,
#   'token': 'The',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 3},
#  {'id': 2,
#   'token': 'doors',
#   'lemma': 'door',
#   'tag': 'NNS',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 3},
#  {'id': 3,
#   'token': 'were',
#   'lemma': 'be',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 0},
#  {'id': 4,
#   'token': 'really',
#   'lemma': 'really',
#   'tag': 'RB',
#   'entity': 'O',
#   'dependency': 'advmod',
#   'head id': 9},
#  {'id': 5,
#   'token': 'small',
#   'lemma': 'small',
#   'tag': 'JJ',
#   'entity': 'O',
#   'dependency': 'acomp',
#   'head id': 9},
#  {'id': 6,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 7},
#  {'id': 1,
#   'token': 'In',
#   'lemma': 'in',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 3},
#  {'id': 2,
#   'token': 'addition',
#   'lemma': 'addition',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 3},
#  {'id': 3,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 0},
#  {'id': 4,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'O',
#   'dependency': 'dep',
#   'head id': 9},
#  {'id': 5,
#   'token': 'the',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 9},
#  {'id': 6,
#   'token': 'front',
#   'lemma': 'front',
#   'tag': 'JJ',
#   'entity': 'O',
#   'dependency': 'amod',
#   'head id': 7},
#  {'id': 7,
#   'token': 'bumper',
#   'lemma': 'bumper',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 5},
#  {'id': 8,
#   'token': 'was',
#   'lemma': 'be',
#   'tag': 'VBD',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 9},
#  {'id': 9,
#   'token': 'separate',
#   'lemma': 'separate',
#   'tag': 'JJ',
#   'entity': 'O',
#   'dependency': 'acomp',
#   'head id': 15},
#  {'id': 10,
#   'token': 'from',
#   'lemma': 'from',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 9},
#  {'id': 11,
#   'token': 'the',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 9},
#  {'id': 12,
#   'token': 'rest',
#   'lemma': 'rest',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 13},
#  {'id': 13,
#   'token': 'of',
#   'lemma': 'of',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 11},
#  {'id': 14,
#   'token': 'the',
#   'lemma': 'the',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 15},
#  {'id': 15,
#   'token': 'body',
#   'lemma': 'body',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 3},
#  {'id': 16,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 15},
#  {'id': 1,
#   'token': 'This',
#   'lemma': 'this',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 3},
#  {'id': 2,
#   'token': 'is',
#   'lemma': 'be',
#   'tag': 'VBZ',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 3},
#  {'id': 3,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'O',
#   'dependency': 'dep',
#   'head id': 0},
#  {'id': 4,
#   'token': 'all',
#   'lemma': 'all',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'attr',
#   'head id': 9},
#  {'id': 5,
#   'token': 'I',
#   'lemma': 'I',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 9},
#  {'id': 6,
#   'token': 'know',
#   'lemma': 'know',
#   'tag': 'VBP',
#   'entity': 'O',
#   'dependency': 'relcl',
#   'head id': 7},
#  {'id': 7,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 5},
#  {'id': 1,
#   'token': 'If',
#   'lemma': 'if',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'mark',
#   'head id': 3},
#  {'id': 2,
#   'token': 'anyone',
#   'lemma': 'anyone',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 3},
#  {'id': 3,
#   'token': 'can',
#   'lemma': 'can',
#   'tag': 'MD',
#   'entity': 'O',
#   'dependency': 'aux',
#   'head id': 0},
#  {'id': 4,
#   'token': 'tellme',
#   'lemma': 'tellme',
#   'tag': 'VB',
#   'entity': 'O',
#   'dependency': 'advcl',
#   'head id': 9},
#  {'id': 5,
#   'token': 'a',
#   'lemma': 'a',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 9},
#  {'id': 6,
#   'token': 'model',
#   'lemma': 'model',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'compound',
#   'head id': 7},
#  {'id': 7,
#   'token': 'name',
#   'lemma': 'name',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 5},
#  {'id': 8,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 9},
#  {'id': 9,
#   'token': 'engine',
#   'lemma': 'engine',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'compound',
#   'head id': 15},
#  {'id': 10,
#   'token': 'specs',
#   'lemma': 'spec',
#   'tag': 'NNS',
#   'entity': 'O',
#   'dependency': 'conj',
#   'head id': 9},
#  {'id': 11,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 9},
#  {'id': 12,
#   'token': 'years',
#   'lemma': 'year',
#   'tag': 'NNS',
#   'entity': 'DATE',
#   'dependency': 'conj',
#   'head id': 13},
#  {'id': 13,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'O',
#   'dependency': 'dep',
#   'head id': 11},
#  {'id': 14,
#   'token': 'of',
#   'lemma': 'of',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 15},
#  {'id': 15,
#   'token': 'production',
#   'lemma': 'production',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 3},
#  {'id': 16,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 15},
#  {'id': 17,
#   'token': 'where',
#   'lemma': 'where',
#   'tag': 'WRB',
#   'entity': 'O',
#   'dependency': 'advmod',
#   'head id': 19},
#  {'id': 18,
#   'token': 'this',
#   'lemma': 'this',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 19},
#  {'id': 19,
#   'token': 'car',
#   'lemma': 'car',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'nsubjpass',
#   'head id': 15},
#  {'id': 20,
#   'token': 'is',
#   'lemma': 'be',
#   'tag': 'VBZ',
#   'entity': 'O',
#   'dependency': 'auxpass',
#   'head id': 3},
#  {'id': 21,
#   'token': 'made',
#   'lemma': 'make',
#   'tag': 'VBN',
#   'entity': 'O',
#   'dependency': 'relcl',
#   'head id': 22},
#  {'id': 22,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 0},
#  {'id': 23,
#   'token': 'history',
#   'lemma': 'history',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'conj',
#   'head id': 28},
#  {'id': 24,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 26},
#  {'id': 25,
#   'token': 'or',
#   'lemma': 'or',
#   'tag': 'CC',
#   'entity': 'O',
#   'dependency': 'cc',
#   'head id': 26},
#  {'id': 26,
#   'token': 'whatever',
#   'lemma': 'whatever',
#   'tag': 'WDT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 28},
#  {'id': 27,
#   'token': 'info',
#   'lemma': 'info',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 28},
#  {'id': 28,
#   'token': 'you',
#   'lemma': 'you',
#   'tag': 'PRP',
#   'entity': 'O',
#   'dependency': 'nsubj',
#   'head id': 22},
#  {'id': 29,
#   'token': '\n',
#   'lemma': '\n',
#   'tag': '_SP',
#   'entity': 'O',
#   'dependency': 'dep',
#   'head id': 22},
#  {'id': 30,
#   'token': 'have',
#   'lemma': 'have',
#   'tag': 'VBP',
#   'entity': 'O',
#   'dependency': 'ROOT',
#   'head id': 22},
#  {'id': 31,
#   'token': 'on',
#   'lemma': 'on',
#   'tag': 'IN',
#   'entity': 'O',
#   'dependency': 'prep',
#   'head id': 32},
#  {'id': 32,
#   'token': 'this',
#   'lemma': 'this',
#   'tag': 'DT',
#   'entity': 'O',
#   'dependency': 'det',
#   'head id': 30},
#  {'id': 33,
#   'token': 'funky',
#   'lemma': 'funky',
#   'tag': 'JJ',
#   'entity': 'O',
#   'dependency': 'amod',
#   'head id': 32},
#  {'id': 34,
#   'token': 'looking',
#   'lemma': 'look',
#   'tag': 'VBG',
#   'entity': 'O',
#   'dependency': 'amod',
#   'head id': 36},
#  {'id': 35,
#   'token': 'car',
#   'lemma': 'car',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'pobj',
#   'head id': 36},
#  {'id': 36,
#   'token': ',',
#   'lemma': ',',
#   'tag': ',',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 33},
#  {'id': 37,
#   'token': 'please',
#   'lemma': 'please',
#   'tag': 'UH',
#   'entity': 'O',
#   'dependency': 'intj',
#   'head id': 36},
#  {'id': 38,
#   'token': 'e',
#   'lemma': 'e',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 39},
#  {'id': 39,
#   'token': '-',
#   'lemma': '-',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 33},
#  {'id': 40,
#   'token': 'mail',
#   'lemma': 'mail',
#   'tag': 'NN',
#   'entity': 'O',
#   'dependency': 'dobj',
#   'head id': 22},
#  {'id': 41,
#   'token': '.',
#   'lemma': '.',
#   'tag': '.',
#   'entity': 'O',
#   'dependency': 'punct',
#   'head id': 43}]

# %%
for word in words:
    if "VB" in word["tag"]:
        print(word["token"])
# Out:
# was
# wondering
# enlighten
# saw
# was
# looked
# be
# was
# called
# were
# was
# is
# know
# tellme
# is
# made
# have
# looking

# %%
visualize_annotation(target)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="95400a489d5e4ac997526dff9ec507ca-0" class="displacy" width="9950" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">wondering</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">if</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">anyone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">there</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">could</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">enlighten</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">me</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">car</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1350">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">saw</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1750">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">day.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1950">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">2-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2350">door</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">sports</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2550">car,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">looked</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2950">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">DET</tspan>
# </text>
#
# <text class="displ

# %%
visualize_annotation("What is the full form of .com?")
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="750de8a70ea4468fb21bfaadcdd88011-0" class="displacy" width="750" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">What</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">full</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">form</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">.com?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-1" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-3" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,204.0 L453.0,192.0 437.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-4" stroke-width="2px" d="M470,202.0 C470,152.0 535.0,152.0 535.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,204.0 L543.0,192.0 527.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-750de8a70ea4468fb21bfaadcdd88011-0-5" stroke-width="2px" d="M170,202.0 C170,2.0 650.0,2.0 650.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-750de8a70ea4468fb21bfaadcdd88011-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,204.0 L658.0,192.0 642.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# Thanks to arrows in the graph, then I'll retrive everything that is connected with the verb for each verb in the sentence
